# %%
# import important stuff
import numpy as np
import pandas as pd

# %%
# import visulization modules
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
sns.set_context("talk")
# %matplotlib inline

import plotly.plotly as py
import plotly.graph_objs as go 
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
# import sklearn modules
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve
from imblearn.under_sampling import RandomUnderSampler
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier

# %%
# import word cloud module 
from os import path
from wordcloud import WordCloud

# import datetime
from datetime import datetime

# %%
# import the data from csv file with a series of NAN values 
df= pd.read_csv('Consumer_Complaints_sample.csv',parse_dates=['Date received', 'Date sent to company'])

# %%
# Overlook of the data set
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104588 entries, 0 to 104587
# Data columns (total 19 columns):
# Unnamed: 0                      104588 non-null int64
# Date received                   104588 non-null datetime64[ns]
# Product                         104588 non-null object
# Sub-product                     81021 non-null object
# Issue                           104588 non-null object
# Sub-issue                       54877 non-null object
# Consumer complaint narrative    28579 non-null object
# Company public response         32819 non-null object
# Company                         104588 non-null object
# State                           103344 non-null object
# ZIP code                        102887 non-null object
# Tags                            14505 non-null object
# Consumer consent provided?      50815 non-null object
# Submitted via                   104588 non-null object
# Date sent to company            104588 non-null datetime64[ns]
# Company response to consumer    104588 non-null object
# Timely response?                104588 non-null object
# Consumer disputed?              76774 non-null object
# Complaint ID                    104588 non-null int64
# dtypes: datetime64[ns](2), int64(2), object(15)
# memory usage: 15.2+ MB

# %%
# Found code and state name data from https://www.census.gov/geo/reference/ansi_statetables.html
# change the code and state name into dictionary for later use.
state_code= pd.read_csv('us states code.csv')
code = state_code['STATE|STUSAB|STATE_NAME|STATENS'].apply(lambda x : x.split('|')[1])
state_name = state_code['STATE|STUSAB|STATE_NAME|STATENS'].apply(lambda x : x.split('|')[2])
state_dict = dict(zip(code, state_name))
state_dict['AA'] = 'American Armed Forces'
state_dict['AE'] = 'American Armed Forces'
state_dict['AP'] = 'American Armed Forces'
state_dict['FM'] = 'Micronesia'
state_dict['MH'] = 'Marshall Islands'
state_dict['PW'] = 'Palau'
state_dict['UNITED STATES MINOR OUTLYING ISLANDS'] = 'UNITED STATES MINOR OUTLYING ISLANDS'

# %%
# build a new data frame of the consumer complaints count and products count for each state. 
state_product = df.groupby('State')['Product_new'].value_counts().unstack().reset_index()
state_count = pd.DataFrame(df['State'].value_counts()).reset_index()
state_count.columns = ['State','Count']
state = state_product.merge(state_count, on = 'State')
product_list = state_product.columns[1:]

# find the most complained product for each state. Find the full name of the each state code. 
# Combine the information into one text column that will be used for interactive plotting next.  
state_max_product = []
state_max_product_count = []
for index, row in state_product.iterrows():
    max_product_count = 0
    state_name_i = state_dict[row['State']]
    for i in product_list:
        if row[i] > max_product_count:
            max_product_count = row[i]
            product_name = i
    state_max_product.append(state_name_i+"<br>"+ product_name+": "+str(max_product_count))
state['state_max_product'] = state_max_product 

state
# Out:
#                                    State  Bank account or service  \
# 0                                     AA                      1.0
# 1                                     AE                      2.0
# 2                                     AK                      7.0
# 3                                     AL                    106.0
# 4                                     AP                      2.0
# 5                                     AR                     34.0
# 6                                     AS                      NaN
# 7                                     AZ                    252.0
# 8                                     CA                   1489.0
# 9                                     CO                    130.0
# 10                                    CT                    149.0
# 11                                    DC                     84.0
# 12                                    DE                     63.0
# 13                                    FL                   1002.0
# 14                                    FM                      2.0
# 15                                    GA                    466.0
# 16                                    GU                      1.0
# 17                                    HI                     28.0
# 18                                    IA                     40.0
# 19                                    ID                     24.0
# 20                                    IL                    461.0
# 21                                    IN                    108.0
# 22                                    KS                     49.0
# 23                                    KY                     66.0
# 24                                    LA                     97.0
# 25                                    MA                    269.0
# 26                                    MD                    342.0
# 27                                    ME                     24.0
# 28                                    MH                      NaN
# 29                                    MI                    236.0
# ..                                   ...                      ...
# 33                                    MS                     46.0
# 34                                    MT                      5.0
# 35                                    NC                    312.0
# 36                                    ND                      5.0
# 37                                    NE                     29.0
# 38                                    NH                     49.0
# 39                                    NJ                    504.0
# 40                                    NM                     26.0
# 41                                    NV                    133.0
# 42                                    NY                    915.0
# 43                                    OH                    318.0
# 44                                    OK                     37.0
# 45                                    OR                    121.0
# 46                                    PA                    454.0
# 47                                    PR                     27.0
# 48                                    PW                      NaN
# 49                                    RI                     39.0
# 50                                    SC                    111.0
# 51                                    SD                      8.0
# 52                                    TN                    125.0
# 53                                    TX                    632.0
# 54  UNITED STATES MINOR OUTLYING ISLANDS                      NaN
# 55                                    UT                     49.0
# 56                                    VA                    329.0
# 57                                    VI                      3.0
# 58                                    VT                     16.0
# 59                                    WA                    198.0
# 60                                    WI                    101.0
# 61                                    WV                     14.0
# 62                                    WY                      7.0
#
#     Credit card or prepaid card  Credit reporting, or other consumer reports  \
# 0                           NaN                                          NaN
# 1                           5.0                                          6.0
# 2                          15.0                                         29.0
# 3                         104.0                                        374.0
# 4                           4.0                                         10.0
# 5                          52.0                                        127.0
# 6                           2.0                                          NaN
# 7                         302.0                                        504.0
# 8                        1608.0                                       3229.0
# 9                         220.0                                        341.0
# 10                        189.0                                        259.0
# 11                         77.0                                        128.0
# 12                         87.0                                        116.0
# 13                        950.0                                       2600.0
# 14                          1.0                                          4.0
# 15                        410.0                                       1654.0
# 16                          2.0                                          4.0
# 17                         39.0                                         64.0
# 18                         80.0                                        142.0
# 19                         42.0                                         66.0
# 20                        458.0                                       1189.0
# 21                        109.0                                        307.0
# 22                         53.0                                        107.0
# 23                         79.0                                        210.0
# 24                         96.0                                        401.0
# 25                        289.0                                        365.0
# 26                        314.0                                        692.0
# 27                         41.0                                         64.0
# 28                          2.0                                          NaN
# 29                        275.0                                        590.0
# ..                          ...                                          ...
# 33                         44.0                                        185.0
# 34                         24.0                                         35.0
# 35                        314.0                                        891.0
# 36                          7.0                                         35.0
# 37                         44.0                                         60.0
# 38                         39.0                                         70.0
# 39                        496.0                                        775.0
# 40                         51.0                                        148.0
# 41                        153.0                                        315.0
# 42                       1148.0                                       1568.0
# 43                        406.0                                        689.0
# 44                         79.0                                        150.0
# 45                        135.0                                        213.0
# 46                        455.0                                        758.0
# 47                         44.0                                         83.0
# 48                          NaN                                          1.0
# 49                         36.0                                         37.0
# 50                        137.0                                        446.0
# 51                         17.0                                         26.0
# 52                        168.0                                        432.0
# 53                        792.0                                       2953.0
# 54                          NaN                                          NaN
# 55                         61.0                                        138.0
# 56                        413.0                                        749.0
# 57                          2.0                                          6.0
# 58                         30.0                                         22.0
# 59                        246.0                                        425.0
# 60                        142.0                                        202.0
# 61                         30.0                                         68.0
# 62                          9.0                                         20.0
#
#     Debt collection  Money transfer, virtual currency, or money service  \
# 0               NaN                                                NaN
# 1               5.0                                                1.0
# 2              28.0                                                3.0
# 3             261.0                                                5.0
# 4               7.0                                                1.0
# 5             101.0                                                5.0
# 6               NaN                                                1.0
# 7             430.0                                               28.0
# 8            2611.0                                              168.0
# 9             336.0                                               23.0
# 10            185.0                                               13.0
# 11            101.0                                               10.0
# 12            115.0                                                3.0
# 13           1889.0                                               93.0
# 14              4.0                                                NaN
# 15           1068.0                                               42.0
# 16              2.0                                                NaN
# 17             69.0                                                1.0
# 18            108.0                                                1.0
# 19             69.0                                                2.0
# 20            721.0                                               42.0
# 21            277.0                                               10.0
# 22            121.0                                                6.0
# 23            185.0                                                9.0
# 24            302.0                                               12.0
# 25            231.0                                               31.0
# 26            504.0                                               24.0
# 27             50.0                                                2.0
# 28              1.0                                                NaN
# 29            519.0                                               31.0
# ..              ...                                                ...
# 33            133.0                                                7.0
# 34             42.0                                                1.0
# 35            556.0                                               25.0
# 36             33.0                                                NaN
# 37             68.0                                                5.0
# 38             51.0                                                3.0
# 39            667.0                                               44.0
# 40             87.0                                                3.0
# 41            283.0                                               15.0
# 42           1107.0                                               93.0
# 43            693.0                                               24.0
# 44            168.0                                               11.0
# 45            210.0                                               11.0
# 46            617.0                                               38.0
# 47             59.0                                                4.0
# 48              NaN                                                NaN
# 49             54.0                                                4.0
# 50            331.0                                               15.0
# 51             38.0                                                1.0
# 52            412.0                                               13.0
# 53           2141.0                                               81.0
# 54              NaN                                                NaN
# 55            124.0                                                9.0
# 56            548.0                                               22.0
# 57              NaN                                                1.0
# 58             23.0                                                1.0
# 59            395.0                                               32.0
# 60            235.0                                               12.0
# 61             65.0                                                4.0
# 62             24.0                                                NaN
#
#     Mortgage  Other financial service  Personal loans  Count  \
# 0        1.0                      NaN             NaN      2
# 1        4.0                      NaN             7.0     30
# 2       17.0                      NaN             4.0    103
# 3      204.0                      NaN           145.0   1199
# 4        5.0                      NaN             5.0     34
# 5       77.0                      NaN            41.0    437
# 6        NaN                      NaN             NaN      3
# 7      580.0                      2.0           205.0   2303
# 8     4353.0                     20.0          1091.0  14569
# 9      463.0                      1.0           167.0   1681
# 10     309.0                      NaN           122.0   1226
# 11     117.0                      3.0            73.0    593
# 12     119.0                      NaN            42.0    545
# 13    2691.0                      8.0           606.0   9839
# 14       2.0                      NaN             NaN     13
# 15    1249.0                      5.0           411.0   5305
# 16       1.0                      NaN             2.0     12
# 17      99.0                      NaN            16.0    316
# 18      82.0                      NaN            49.0    502
# 19      88.0                      NaN            31.0    322
# 20     863.0                      2.0           330.0   4066
# 21     202.0                      NaN           148.0   1161
# 22     108.0                      1.0            49.0    494
# 23     158.0                      NaN            64.0    771
# 24     237.0                      1.0           113.0   1259
# 25     525.0                      2.0           183.0   1895
# 26     911.0                      4.0           282.0   3073
# 27      92.0                      NaN            26.0    299
# 28       3.0                      NaN             NaN      6
# 29     687.0                      3.0           226.0   2567
# ..       ...                      ...             ...    ...
# 33     109.0                      NaN            71.0    595
# 34      29.0                      NaN            18.0    154
# 35     793.0                      3.0           255.0   3149
# 36      11.0                      NaN             6.0     97
# 37      60.0                      NaN            43.0    309
# 38     147.0                      NaN            42.0    401
# 39    1211.0                      2.0           336.0   4035
# 40      96.0                      2.0            54.0    467
# 41     302.0                      NaN           102.0   1303
# 42    1674.0                      8.0           568.0   7081
# 43     675.0                      3.0           391.0   3199
# 44     124.0                      1.0            79.0    649
# 45     340.0                      2.0            86.0   1118
# 46     862.0                      6.0           389.0   3579
# 47      44.0                      NaN            23.0    284
# 48       1.0                      NaN             NaN      2
# 49      82.0                      NaN            24.0    276
# 50     291.0                      2.0           161.0   1494
# 51      22.0                      NaN            12.0    124
# 52     319.0                      1.0           186.0   1656
# 53    1346.0                      6.0           732.0   8683
# 54       1.0                      NaN             NaN      1
# 55     138.0                      NaN            40.0    559
# 56     867.0                      3.0           301.0   3232
# 57       3.0                      NaN             NaN     15
# 58      34.0                      NaN            16.0    142
# 59     586.0                      1.0           183.0   2066
# 60     264.0                      3.0           124.0   1083
# 61      50.0                      NaN            32.0    263
# 62      20.0                      NaN            11.0     91
#
#                                     state_max_product
# 0   American Armed Forces<br>Bank account or servi...
# 1        American Armed Forces<br>Personal loans: 7.0
# 2   Alaska<br>Credit reporting, or other consumer ...
# 3   Alabama<br>Credit reporting, or other consumer...
# 4   American Armed Forces<br>Credit reporting, or ...
# 5   Arkansas<br>Credit reporting, or other consume...
# 6   American Samoa<br>Credit card or prepaid card:...
# 7                          Arizona<br>Mortgage: 580.0
# 8                      California<br>Mortgage: 4353.0
# 9                         Colorado<br>Mortgage: 463.0
# 10                     Connecticut<br>Mortgage: 309.0
# 11  District of Columbia<br>Credit reporting, or o...
# 12                        Delaware<br>Mortgage: 119.0
# 13                        Florida<br>Mortgage: 2691.0
# 14  Micronesia<br>Credit reporting, or other consu...
# 15  Georgia<br>Credit reporting, or other consumer...
# 16  Guam<br>Credit reporting, or other consumer re...
# 17                           Hawaii<br>Mortgage: 99.0
# 18  Iowa<br>Credit reporting, or other consumer re...
# 19                            Idaho<br>Mortgage: 88.0
# 20  Illinois<br>Credit reporting, or other consume...
# 21  Indiana<br>Credit reporting, or other consumer...
# 22                   Kansas<br>Debt collection: 121.0
# 23  Kentucky<br>Credit reporting, or other consume...
# 24  Louisiana<br>Credit reporting, or other consum...
# 25                   Massachusetts<br>Mortgage: 525.0
# 26                        Maryland<br>Mortgage: 911.0
# 27                            Maine<br>Mortgage: 92.0
# 28                  Marshall Islands<br>Mortgage: 3.0
# 29                        Michigan<br>Mortgage: 687.0
# ..                                                ...
# 33  Mississippi<br>Credit reporting, or other cons...
# 34                   Montana<br>Debt collection: 42.0
# 35  North Carolina<br>Credit reporting, or other c...
# 36  North Dakota<br>Credit reporting, or other con...
# 37                  Nebraska<br>Debt collection: 68.0
# 38                   New Hampshire<br>Mortgage: 147.0
# 39                     New Jersey<br>Mortgage: 1211.0
# 40  New Mexico<br>Credit reporting, or other consu...
# 41  Nevada<br>Credit reporting, or other consumer ...
# 42                       New York<br>Mortgage: 1674.0
# 43                     Ohio<br>Debt collection: 693.0
# 44                 Oklahoma<br>Debt collection: 168.0
# 45                          Oregon<br>Mortgage: 340.0
# 46                    Pennsylvania<br>Mortgage: 862.0
# 47  Puerto Rico<br>Credit reporting, or other cons...
# 48  Palau<br>Credit reporting, or other consumer r...
# 49                     Rhode Island<br>Mortgage: 82.0
# 50  South Carolina<br>Credit reporting, or other c...
# 51              South Dakota<br>Debt collection: 38.0
# 52  Tennessee<br>Credit reporting, or other consum...
# 53  Texas<br>Credit reporting, or other consumer r...
# 54  UNITED STATES MINOR OUTLYING ISLANDS<br>Mortga...
# 55  Utah<br>Credit reporting, or other consumer re...
# 56                        Virginia<br>Mortgage: 867.0
# 57  U.S. Virgin Islands<br>Credit reporting, or ot...
# 58                          Vermont<br>Mortgage: 34.0
# 59                      Washington<br>Mortgage: 586.0
# 60                       Wisconsin<br>Mortgage: 264.0
# 61  West Virginia<br>Credit reporting, or other co...
# 62                   Wyoming<br>Debt collection: 24.0
#
# [63 rows x 11 columns]

# %%
plotly_data = dict(type='choropleth',
            colorscale = 'YIOrRd',
            locations = state['State'],
            z = state['Count'],
            locationmode = 'USA-states',
            text = state['state_max_product'],
            marker = dict(line = dict(color = 'rgb(255,255,255)',width = 2)),
            colorbar = {'title':"Millions USD"}
            ) 

layout = dict(title = 'Financial Products Consumer Complaints by State',
              geo = dict(scope='usa',
                         showlakes = True,
                         lakecolor = 'rgb(85,173,240)')
             )

# %%
choromap = go.Figure(data = [plotly_data],layout = layout)
iplot(choromap)
# Out:
# <div id="a8dfb6b7-8b2f-4063-be51-924449eb4fcc" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("a8dfb6b7-8b2f-4063-be51-924449eb4fcc", [{"type": "choropleth", "colorscale": "YIOrRd", "locations": ["AA", "AE", "AK", "AL", "AP", "AR", "AS", "AZ", "CA", "CO", "CT", "DC", "DE", "FL", "FM", "GA", "GU", "HI", "IA", "ID", "IL", "IN", "KS", "KY", "LA", "MA", "MD", "ME", "MH", "MI", "MN", "MO", "MP", "MS", "MT", "NC", "ND", "NE", "NH", "NJ", "NM", "NV", "NY", "OH", "OK", "OR", "PA", "PR", "PW", "RI", "SC", "SD", "TN", "TX", "UNITED STATES MINOR OUTLYING ISLANDS", "UT", "VA", "VI", "VT", "WA", "WI", "WV", "WY"], "z": [2, 30, 103, 1199, 34, 437, 3, 2303, 14569, 1681, 1226, 593, 545, 9839, 13, 5305, 12, 316, 502, 322, 4066, 1161, 494, 771, 1259, 1895, 3073, 299, 6, 2567, 1150, 1461, 1, 595, 154, 3149, 97, 309, 401, 4035, 467, 1303, 7081, 3199, 649, 1118, 3579, 284, 2, 276, 1494, 124, 1656, 8683, 1, 559, 3232, 15, 142, 2066, 1083, 263, 91], "locationmode": "USA-states", "text": ["American Armed Forces<br>Bank account or service: 1.0", "American Armed Forces<br>Personal loans: 7.0", "Alaska<br>Credit reporting, or other consumer reports: 29.0", "Alabama<br>Credit reporting, or other consumer reports: 374.0", "American Armed Forces<br>Credit reporting, or other consumer reports: 10.0", "Arkansas<br>Credit reporting, or other consumer reports: 127.0", "American Samoa<br>Credit card or prepaid card: 2.0", "Arizona<br>Mortgage: 580.0", "California<br>Mortgage: 4353.0", "Colorado<br>Mortgage: 463.0", "Connecticut<br>Mortgage: 309.0", "District of Columbia<br>Credit reporting, or other consumer reports: 128.0", "Delaware<br>Mortgage: 119.0", "Florida<br>Mortgage: 2691.0", "Micronesia<br>Credit reporting, or other consumer reports: 4.0", "Georgia<br>Credit reporting, or other consumer reports: 1654.0", "Guam<br>Credit reporting, or other consumer reports: 4.0", "Hawaii<br>Mortgage: 99.0", "Iowa<br>Credit reporting, or other consumer reports: 142.0", "Idaho<br>Mortgage: 88.0", "Illinois<br>Credit reporting, or other consumer reports: 1189.0", "Indiana<br>Credit reporting, or other consumer reports: 307.0", "Kansas<br>Debt collection: 121.0", "Kentucky<br>Credit reporting, or other consumer reports: 210.0", "Louisiana<br>Credit reporting, or other consumer reports: 401.0", "Massachusetts<br>Mortgage: 525.0", "Maryland<br>Mortgage: 911.0", "Maine<br>Mortgage: 92.0", "Marshall Islands<br>Mortgage: 3.0", "Michigan<br>Mortgage: 687.0", "Minnesota<br>Mortgage: 327.0", "Missouri<br>Credit reporting, or other consumer reports: 390.0", "Northern Mariana Islands<br>Credit reporting, or other consumer reports: 1.0", "Mississippi<br>Credit reporting, or other consumer reports: 185.0", "Montana<br>Debt collection: 42.0", "North Carolina<br>Credit reporting, or other consumer reports: 891.0", "North Dakota<br>Credit reporting, or other consumer reports: 35.0", "Nebraska<br>Debt collection: 68.0", "New Hampshire<br>Mortgage: 147.0", "New Jersey<br>Mortgage: 1211.0", "New Mexico<br>Credit reporting, or other consumer reports: 148.0", "Nevada<br>Credit reporting, or other consumer reports: 315.0", "New York<br>Mortgage: 1674.0", "Ohio<br>Debt collection: 693.0", "Oklahoma<br>Debt collection: 168.0", "Oregon<br>Mortgage: 340.0", "Pennsylvania<br>Mortgage: 862.0", "Puerto Rico<br>Credit reporting, or other consumer reports: 83.0", "Palau<br>Credit reporting, or other consumer reports: 1.0", "Rhode Island<br>Mortgage: 82.0", "South Carolina<br>Credit reporting, or other consumer reports: 446.0", "South Dakota<br>Debt collection: 38.0", "Tennessee<br>Credit reporting, or other consumer reports: 432.0", "Texas<br>Credit reporting, or other consumer reports: 2953.0", "UNITED STATES MINOR OUTLYING ISLANDS<br>Mortgage: 1.0", "Utah<br>Credit reporting, or other consumer reports: 138.0", "V ...

# %%
month_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
day_order = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']

# %%
df['receive month'] = df['Date received'].apply(lambda x: month_order[x.month-1])

month_df = pd.DataFrame(df['receive month'].value_counts()).reset_index()
month_df.columns = ['Month', 'Complaints']

# %%
sns.barplot(x='Month', y='Complaints', data=month_df, order=month_order)
plt.title('Number of Complaints By Month',fontsize=14)
sns.despine()
plt.xlabel('')
plt.ylabel('')
plt.savefig('./../results/monthly_complaints.png',dpi = 150)
sns.set_style('whitegrid')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-138-0c6a083eaa77> in <module>()
#       4 plt.xlabel('')
#       5 plt.ylabel('')
# ----> 6 plt.savefig('./../results/monthly_complaints.png',dpi = 150)
#       7 sns.set_style('whitegrid')
#
# /anaconda/lib/python3.6/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     695 def savefig(*args, **kwargs):
#     696     fig = gcf()
# --> 697     res = fig.savefig(*args, **kwargs)
#     698     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     699     return res
#
# /anaconda/lib/python3.6/site-packages/matplotlib/figure.py in savefig(self, *args, **kwargs)
#    1571             self.set_frameon(frameon)
#    1572
# -> 1573         self.canvas.print_figure(*args, **kwargs)
#    1574
#    1575         if frameon:
#
# /anaconda/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2250                 orientation=orientation,
#    2251                 bbox_inches_restore=_bbox_inches_restore,
# -> 2252                 **kwargs)
#    2253         finally:
#    2254             if bbox_inches and restore_bbox:
#
# /anaconda/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     548         renderer.dpi = self.figure.dpi
#     549         if is_string_like(filename_or_obj):
# --> 550             filename_or_obj = open(filename_or_obj, 'wb')
#     551             close = True
#     552         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: './../results/monthly_complaints.png'

# %%
# consumer complaints by day of the week

# %%
df['receive weekday'] = df['Date received'].apply(lambda x: day_order[x.weekday()])


weekday_df = pd.DataFrame(df['receive weekday'].value_counts()).reset_index()
weekday_df.columns = ['WeekDate', 'Complaints']

# %%
sns.barplot(x='WeekDate', y='Complaints', data=weekday_df, order=day_order)

# %%
# consumer complaints of mortgage products by day of the week

# %%
weekday_mortgage_df = pd.DataFrame(df[df['Product_new']=='Mortgage']['receive weekday'].value_counts()).reset_index()
weekday_mortgage_df.columns = ['WeekDate', 'Complaints']
sns.barplot(x='WeekDate', y='Complaints', data=weekday_mortgage_df, order=day_order)

# %%
df['Year'] = df['Date received'].apply(lambda x: x.year)

# %%
df_year = pd.DataFrame(df['Year'].value_counts().reset_index())
df_year.columns=['Year', 'Complaints']
plt.figure(figsize=(16,6))
sns.pointplot(x='Year', y='Complaints', data=df_year)
plt.ylabel('Number of Complaints')

# %%
#how many complaints for each financial product?
df['Product'].value_counts()
# Out:
# Mortgage                                                                        25629
# Debt collection                                                                 20180
# Credit reporting                                                                13947
# Credit reporting, credit repair services, or other personal consumer reports    11963
# Credit card                                                                      9049
# Bank account or service                                                          8534
# Student loan                                                                     4429
# Consumer Loan                                                                    3004
# Credit card or prepaid card                                                      2487
# Checking or savings account                                                      2135
# Vehicle loan or lease                                                             616
# Money transfer, virtual currency, or money service                                597
# Payday loan                                                                       571
# Money transfers                                                                   561
# Payday loan, title loan, or personal loan                                         454
# Prepaid card                                                                      331
# Other financial service                                                            98
# Virtual currency                                                                    3
# Name: Product, dtype: int64

# %%
# The product list above seem overlapping with each other. Check the appearance year of the complaints for each product. 
df.groupby('Product')['Year'].value_counts(normalize=True).unstack()
# Out:
# Year                                                    2011      2012  \
# Product
# Bank account or service                                  NaN  0.136864
# Checking or savings account                              NaN       NaN
# Consumer Loan                                            NaN  0.059920
# Credit card                                         0.014698  0.169853
# Credit card or prepaid card                              NaN       NaN
# Credit reporting                                         NaN  0.013838
# Credit reporting, credit repair services, or ot...       NaN       NaN
# Debt collection                                          NaN       NaN
# Money transfer, virtual currency, or money service       NaN       NaN
# Money transfers                                          NaN       NaN
# Mortgage                                            0.005072  0.149596
# Other financial service                                  NaN       NaN
# Payday loan                                              NaN       NaN
# Payday loan, title loan, or personal loan                NaN       NaN
# Prepaid card                                             NaN       NaN
# Student loan                                             NaN  0.060962
# Vehicle loan or lease                                    NaN       NaN
# Virtual currency                                         NaN       NaN
#
# Year                                                    2013      2014  \
# Product
# Bank account or service                             0.154910  0.168620
# Checking or savings account                              NaN       NaN
# Consumer Loan                                       0.094208  0.174434
# Credit card                                         0.152835  0.151508
# Credit card or prepaid card                              NaN       NaN
# Credit reporting                                    0.104395  0.208289
# Credit reporting, credit repair services, or ot...       NaN       NaN
# Debt collection                                     0.053865  0.189841
# Money transfer, virtual currency, or money service       NaN       NaN
# Money transfers                                     0.092692  0.208556
# Mortgage                                            0.191775  0.172188
# Other financial service                                  NaN  0.112245
# Payday loan                                         0.029772  0.339755
# Payday loan, title loan, or personal loan                NaN       NaN
# Prepaid card                                             NaN  0.090634
# Student loan                                        0.061413  0.104538
# Vehicle loan or lease                                    NaN       NaN
# Virtual currency                                         NaN       NaN
#
# Year                                                    2015      2016  \
# Product
# Bank account or service                             0.207288  0.247715
# Checking or savings account                              NaN       NaN
# Consumer Loan                                       0.240679  0.315246
# Credit card                                         0.197922  0.233396
# Credit card or prepaid card                              NaN       NaN
# Credit reporting                                    0.251309  0.310533
# Credit reporting, credit repair services, or ot...       NaN       NaN
# Debt collection                                     0.202131  0.201041
# Money transfer, virtual currency, or money service       NaN       NaN
# Money transfers                                     0.301248  0.310160
# Mortgage                                            0.165282  0.158258
# Other financial service                             0.265306  0.418367
# Payday loan                                         0.241681  0.315236
# Payday loan, title loan, or personal loan                NaN       NaN
# Prepaid card                                        0.459215  0.311178
# Student loan                                        0.110860  0.184014
# Vehicle loan or lease                                    NaN       NaN
# Virtual currency                                    0.666667  0.333333
#
# Year                                                    2017      2018
# Product
# Bank account or service                             0.084603       NaN
# Checking or savings account                         0.613115  0.386885
# Consumer Loan                                       0.115513       NaN
# Credit card                                         0.079788       NaN
# Credit card or prepaid card                         0.608766  0.391234
# Credit reporting                                    0.111637       NaN
# Credit reporting, credit repair services, or ot...  0.618156  0.381844
# Debt collection                                     0.240833  0.112289
# Money transfer, virtual currency, or money service  0.534338  0.465662
# Money transfers                                     0.087344       NaN
# Mortgage                                            0.117913  0.039916
# Other financial service                             0.204082       NaN
# Payday loan                                         0.073555       NaN
# Payday loan, title loan, or personal loan           0.627753  0.372247
# Prepaid card                                        0.138973       NaN
# Student loan                                        0.394897  0.083315
# Vehicle loan or lease                               0.589286  0.410714
# Virtual currency                                         NaN       NaN

# %% [markdown]
# ### Many of the product in the list were changed over the years. For example, credit card, prepaid card were in earlier years but stopped (NaN) after 2017. Instead Credit card or prepaid card feature only appears in later years. Next, I combine some of the products to simplify the product feature. This also makes it more consistent over the years.

# %%
#Many products seem to be replications. Define a function here to fix that.
def categorize_feature(ls):
    new_ls = []
    for i, prod in enumerate(ls):
        if prod in ['Credit reporting', 'Credit reporting, credit repair services, or other personal consumer reports']:
            new_ls.append('Credit reporting, or other consumer reports')
        elif prod in ['Credit card', 'Prepaid card', 'Credit card or prepaid card']:
            new_ls.append('Credit card or prepaid card')
        elif prod in ['Student loan', 'Consumer Loan', 'Vehicle loan or lease', 'Payday loan', 'Payday loan, title loan, or personal loan']:
            new_ls.append('Personal loans')
        elif prod in ['Money transfer, virtual currency, or money service', 'Money transfers', 'Virtual currency']:
            new_ls.append('Money transfer, virtual currency, or money service')
        elif prod in ['Checking or savings account', 'Bank account or service']:
            new_ls.append('Bank account or service')
        else:
            new_ls.append(prod)
    return new_ls

new_list = categorize_feature(df['Product'])

# %%
df['Product_new'] = pd.Series(new_list)

# %%
# Value counts of the simplified product list 
product_order = pd.Series(new_list).value_counts().index
print('How many complaints per product:')
print(pd.Series(new_list).value_counts())

sns.countplot(data=df, x='Product_new', order = product_order)
plt.xticks(rotation=40, ha="right")
# Out:
# How many complaints per product:
# Credit reporting, or other consumer reports           25910
# Mortgage                                              25629
# Debt collection                                       20180
# Credit card or prepaid card                           11867
# Bank account or service                               10669
# Personal loans                                         9074
# Money transfer, virtual currency, or money service     1161
# Other financial service                                  98
# dtype: int64
# (array([0, 1, 2, 3, 4, 5, 6, 7]), <a list of 8 Text xticklabel objects>)

# %%
# Percentage of complaints being disputed for the simplified products

df_dispute = df.dropna(axis=0, subset=['Consumer disputed?'])
df_dispute_product = df_dispute.groupby('Product_new')['Consumer disputed?'].value_counts(normalize=True).unstack().reset_index()

sns.barplot(data=df_dispute_product, x='Product_new', y='Yes',order = product_order, color='red')
df_dispute_product

#sns.barplot(data=df_dispute, x='Product_new', hue='Consumer disputed?',order = pd.Series(new_list).value_counts().index)
plt.xticks(rotation=40, ha="right")
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]), <a list of 8 Text xticklabel objects>)

# %%
# check the sub-product feature:
df[df['Product_new']=='Mortgage']['Sub-product'].value_counts()
# Out:
# Other mortgage                                8811
# Conventional fixed mortgage                   6913
# FHA mortgage                                  2827
# Conventional adjustable mortgage (ARM)        2603
# Conventional home mortgage                    1573
# Home equity loan or line of credit            1167
# VA mortgage                                    672
# Other type of mortgage                         575
# Reverse mortgage                               234
# Home equity loan or line of credit (HELOC)     194
# Second mortgage                                 60
# Name: Sub-product, dtype: int64

# %%
# check the value counts of the 'Issue' feature
df['Issue'].value_counts()
df['Issue'].nunique()
# Out:
# 163

# %%
# Word cloud from issue

all_tags = []
for iter_row, row in df.iterrows():
    my_tags = row['Issue'].split(',')
    for tag in my_tags:
        all_tags.append(tag)
all_tags

#Read the whole text.
text = ' '.join(all_tags)

text
# Generate a word cloud image
wordcloud = WordCloud(max_font_size=40).generate(text)

# Display the generated image:
# the matplotlib way:
import matplotlib.pyplot as plt
plt.figure(figsize=(16,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")

plt.show()

# %%
top_issue = list(pd.DataFrame(df['Issue'].value_counts()[0:30]).index)

df_top_issue = df[df['Issue'].isin(top_issue)]

# %%
df_top_issue['Issue'].value_counts().head(5)
# Out:
# Loan modification,collection,foreclosure    11305
# Incorrect information on credit report      10198
# Loan servicing, payments, escrow account     7744
# Incorrect information on your report         6809
# Cont'd attempts collect debt not owed        6169
# Name: Issue, dtype: int64

# %%
top_company = list(pd.DataFrame(df_top_issue.Company.value_counts()[0:30]).index)
df_top_issue_comp = df_top_issue[df_top_issue['Company'].isin(top_company)]

# %%
df_top_issue_comp['Company'].value_counts().head(5)
# Out:
# EQUIFAX, INC.                             7863
# Experian Information Solutions Inc.       7055
# TRANSUNION INTERMEDIATE HOLDINGS, INC.    6329
# BANK OF AMERICA, NATIONAL ASSOCIATION     6116
# WELLS FARGO & COMPANY                     5121
# Name: Company, dtype: int64

# %%
# choose categoric columns that we are using for initial test
categoric = df_top_issue_comp[['Product','Issue', 'Company', 'Consumer consent provided?', 'Submitted via', 'Timely response?', 'Company response to consumer']]
target_d = df_top_issue_comp['Consumer disputed?']

# %%
df_dummy_cate = pd.get_dummies(data=categoric, drop_first=True)
target_dummy = pd.get_dummies(data=target_d, drop_first=True)
df_dummy = df_dummy_cate.join(target_dummy)

# %%
#df_dummy.corr()['Yes']

# %%
#check how many complaints were disputed for each company response. 
print(df_top_issue_comp.groupby('Company response to consumer')['Consumer disputed?'].value_counts(normalize=True).unstack().reset_index())
df_response = df_top_issue_comp.groupby('Company response to consumer')['Consumer disputed?'].value_counts(normalize=True).unstack().reset_index()
df_response.dropna(subset=['Yes'], inplace=True)
sns.barplot(y='Company response to consumer', x='Yes', data = df_response)
plt.xlabel('Complaint disputed')
# Out:
# Consumer disputed?     Company response to consumer        No       Yes
# 0                                            Closed  0.760540  0.239460
# 1                           Closed with explanation  0.790760  0.209240
# 2                       Closed with monetary relief  0.900292  0.099708
# 3                   Closed with non-monetary relief  0.879123  0.120877
# 4                                Closed with relief  0.840000  0.160000
# 5                             Closed without relief  0.727124  0.272876
# 6                                 Untimely response  1.000000       NaN

# %%
# find the values counts of the public response from companies
df_company_response = df.dropna(axis=0, subset=['Company public response'])
print(df_company_response['Company public response'].value_counts())
df_company_response_order = df_company_response['Company public response'].value_counts().index[0:-1]
# Out:
# Company has responded to the consumer and the CFPB and chooses not to provide a public response                            20681
# Company chooses not to provide a public response                                                                            5349
# Company believes it acted appropriately as authorized by contract or law                                                    4893
# Company believes the complaint is the result of a misunderstanding                                                           472
# Company disputes the facts presented in the complaint                                                                        403
# Company believes complaint is the result of an isolated error                                                                317
# Company believes complaint caused principally by actions of third party outside the control or direction of the company      305
# Company can't verify or dispute the facts in the complaint                                                                   202
# Company believes complaint represents an opportunity for improvement to better serve consumers                               193
# Company believes complaint relates to a discontinued policy or procedure                                                       4
# Name: Company public response, dtype: int64
# Index(['Company has responded to the consumer and the CFPB and chooses not to provide a public response',
#        'Company chooses not to provide a public response',
#        'Company believes it acted appropriately as authorized by contract or law',
#        'Company believes the complaint is the result of a misunderstanding',
#        'Company disputes the facts presented in the complaint',
#        'Company believes complaint is the result of an isolated error',
#        'Company believes complaint caused principally by actions of third party outside the control or direction of the company',
#        'Company can't verify or dispute the facts in the complaint',
#        'Company believes complaint represents an opportunity for improvement to better serve consumers'],
#       dtype='object')

# %%
# disputed rate for public company responses
df_company_response_dispute = df_company_response.dropna(axis=0, subset=['Consumer disputed?'])
df_company_response_dispute_rate=df_company_response_dispute.groupby('Company public response')['Consumer disputed?'].value_counts(normalize=True).unstack().reset_index()
# set value to 0 instead of NaN for one input.
df_company_response_dispute_rate.at[2, 'Yes'] =0
sns.barplot(y='Company public response', x='Yes', data = df_company_response_dispute_rate.sort_values('Yes'), palette='Greens')
plt.xlabel('Complaint disputed')

# %%
df['narative_bool'] = pd.isnull(df['Consumer complaint narrative'])

# %%
df['narative_int'] = df['narative_bool'].astype(int)

# %%
# did narrative or not have an effect on dispute?
df.groupby('Consumer disputed?')['narative_bool'].value_counts(normalize=True).unstack()
# Out:
# narative_bool          False     True
# Consumer disputed?
# No                  0.205160  0.794840
# Yes                 0.243906  0.756094

# %%
# any product particularly easy to be disputed?
df_product = df.groupby('Product')['Consumer disputed?'].value_counts(normalize=True).unstack().reset_index()[:-1]
sns.barplot(y='Product', x='Yes', data = df_product.sort_values('Yes'), palette='Blues')
plt.xlabel('Complaint disputed')

# %%
#most appeared companies VS disputed?
df_comp = df_top_issue_comp.groupby('Company')['Consumer disputed?'].value_counts(normalize=True).unstack().reset_index()
sns.barplot(y='Company', x='Yes', data = df_comp.sort_values('Yes'))
plt.xlabel('Complaint disputed')

# %%
df_narative = df.dropna(axis=0, subset=['Consumer complaint narrative'])
df_narative['NarativeLength'] = [len(nara) for nara in df_narative['Consumer complaint narrative']]
# length of the narrative VS consumer disputed?
sns.distplot(data=df_narative, y='NarativeLength', x='Consumer disputed?')
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-135-f7102251fc81> in <module>()
#       2 df_narative['NarativeLength'] = [len(nara) for nara in df_narative['Consumer complaint narrative']]
#       3 # length of the narrative VS consumer disputed?
# ----> 4 sns.distplot(data=df_narative, y='NarativeLength', x='Consumer disputed?')
#
# TypeError: distplot() got an unexpected keyword argument 'data'

# %%
#check how many complaints were disputed. 
sns.countplot(df['Consumer disputed?'])

# %%
# drop the rows where 'consumer disputed?' is missing
df.dropna(axis=0, subset=['Consumer disputed?'], inplace=True)

# %%
df_nara_bool = df_top_issue_comp['Consumer complaint narrative'].fillna(0)

df_nara_bool2=[]
for nara in df_nara_bool:
    if nara is not 0:
        df_nara_bool2.append(1)
    else: 
        df_nara_bool2.append(0)
        
df_top_issue_comp['Narrative_bool'] = df_nara_bool2
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
df_top_issue_comp_short = df_top_issue_comp.drop(['Unnamed: 0', 'Sub-issue', 'Company public response', 'Consumer consent provided?', 'State', 'ZIP code', 'Date sent to company', 'Date received', 'Consumer complaint narrative','Complaint ID', 'Tags'],axis=1)

# %%
df_top_issue_comp_short.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48386 entries, 0 to 104587
# Data columns (total 9 columns):
# Product                         48386 non-null object
# Sub-product                     30844 non-null object
# Issue                           48386 non-null object
# Company                         48386 non-null object
# Submitted via                   48386 non-null object
# Company response to consumer    48386 non-null object
# Timely response?                48386 non-null object
# Consumer disputed?              48386 non-null object
# Narrative_bool                  48386 non-null int64
# dtypes: int64(1), object(8)
# memory usage: 4.9+ MB

# %%
df_dummies = pd.get_dummies(data=df_top_issue_comp_short.drop(['Consumer disputed?','Narrative_bool'], axis=1), drop_first=True)

# %%
df_dummies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48386 entries, 0 to 104587
# Columns: 102 entries, Product_Consumer Loan to Timely response?_Yes
# dtypes: uint8(102)
# memory usage: 6.3 MB

# %%
# Identify variables
X = df_dummies.join(df_top_issue_comp_short['Narrative_bool'])
target_map = {'Yes': 1, 'No':0}
y = df_top_issue_comp['Consumer disputed?'].map(target_map)

# Splitting into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.7, random_state=41)


rus = RandomUnderSampler(random_state=41)
X_rus, y_rus = rus.fit_sample(X=X_train, y=y_train)
X_rus_test, y_rus_test = rus.fit_sample(X=X_test, y=y_test)

print('Raw Training Set Percent Yes: {:.1f}%'.format(
    len(y_train[y_train == 1])/len(y_train)*100))
print('Resampled Training Set Percent Yes: {}%'.format(
    len(y_rus[y_rus == 1])/len(y_rus)*100))
# Out:
# Raw Training Set Percent Yes: 19.8%
# Resampled Training Set Percent Yes: 50.0%

# %%
#Random forest classifier parameter optimization:

rf = RandomForestClassifier()
param_grid = {"n_estimators": [100, 200, 300],
              "max_features": [75, 100],
              "max_depth": [3, 5, 10]
              }

grid_rf = GridSearchCV(rf, param_grid=param_grid, cv=5)
grid_rf.fit(X_rus, y_rus)

# Printing the best score from the model
print('Best Score:', grid_rf.best_score_)

# Saving and printing the best parameters from the model
best_params = grid_rf.best_params_
print('Best Parameters:', best_params)
# Out:
# Best Score: 0.580201809325
# Best Parameters: {'max_depth': 5, 'max_features': 75, 'n_estimators': 100}

# %%
#initiate a instance for classifier
rf = RandomForestClassifier(**best_params)

# Fit the classifier to the training data
rf.fit(X_rus, y_rus)

# Predict the labels of the test data: y_pred
y_pred = rf.predict(X_rus_test)

scores_rf_train = cross_val_score(rf, X_rus, y_rus, cv=5)
print('Cross Validation Accuracy Scores - Training Set: {:.5f}(+/- {:.2f})'.format(scores_rf_train.mean(), 
                                                                                 scores_rf_train.std()*2))
scores_rf_test = cross_val_score(rf, X_rus_test, y_rus_test, cv=5)
print('Cross Validation Accuracy Scores - Test Set: {:.5f}(+/- {:.2f})'.format(scores_rf_test.mean(), 
                                                                                 scores_rf_test.std()*2))

# Generate the confusion matrix and classification report
print('Confusion matrix on the test data:')
print(confusion_matrix(y_rus_test, y_pred))
print('Classification report on the test data:')
print(classification_report(y_rus_test, y_pred))
# Out:
# Cross Validation Accuracy Scores - Training Set: 0.58003(+/- 0.02)
# Cross Validation Accuracy Scores - Test Set: 0.58997(+/- 0.01)
# Confusion matrix on the test data:
# [[3495 3024]
#  [2430 4089]]
# Classification report on the test data:
#              precision    recall  f1-score   support
#
#           0       0.59      0.54      0.56      6519
#           1       0.57      0.63      0.60      6519
#
# avg / total       0.58      0.58      0.58     13038

# %%
len(X)
# Out:
# 48386

# %%
df_narative = df.dropna(axis=0, subset=['Consumer complaint narrative'])
df_narative['NarativeLength'] = [len(nara) for nara in df_narative['Consumer complaint narrative']]
# length of the narrative VS consumer disputed?
sns.barplot(data=df_narative, y='NarativeLength', x='Consumer disputed?')
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_narative.hist(column='NarativeLength', by='Consumer disputed?', bins=50,figsize=(12,4))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11ba85080>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1245d6e80>], dtype=object)

# %%
df_narrative_bool = df.groupby('Narrative_bool')['Consumer disputed?'].value_counts(normalize=True).unstack().reset_index()
df_narrative_bool
sns.barplot(x='Narrative_bool', y='Yes', data = df_narrative_bool.sort_values('Yes'))
plt.ylabel('Complaint disputed')
plt.xlabel('Whether Consumer Authorize Narrative')

# %%
#nltk.download_shell()

# %%
import string
from nltk.corpus import stopwords


def text_process(mess):
    """
    Takes in a string of text, then performs the following:
    1. Remove all punctuation
    2. Remove all stopwords
    3. Returns a list of the cleaned text
    """
    # Check characters to see if they are in punctuation
    nopunc = [char for char in mess if char not in string.punctuation]

    # Join the characters again to form the string.
    nopunc = ''.join(nopunc)
    
    # Now just remove any stopwords
    return [word for word in nopunc.split() if word.lower() not in stopwords.words('english')]

# %%
df_narative['Consumer disputed?'].value_counts()
# Out:
# No     12738
# Yes     3582
# Name: Consumer disputed?, dtype: int64

# %%
df_narative['Consumer complaint narrative'].head(1).apply(text_process)
# Out:
# 2    [credit, score, ran, 2, times, Spring, Leaf, n...
# Name: Consumer complaint narrative, dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
# Might take awhile...
bow_transformer = CountVectorizer(analyzer=text_process).fit(df_narative['Consumer complaint narrative'])

# Print total number of vocab words
print(len(bow_transformer.vocabulary_))
# Out:
# 38204

# %%
narrative0 = df_narative['Consumer complaint narrative'].head(1)
print(narrative0)
bow0 = bow_transformer.transform([narrative0])
# Out:
# 2    I had my credit score ran 2 times by Spring Le...
# Name: Consumer complaint narrative, dtype: object

# %%
narrative_bow = bow_transformer.transform(df_narative['Consumer complaint narrative'])

# %%
print('Shape of Sparse Matrix: ', narrative_bow.shape)
print('Amount of Non-Zero occurences: ', narrative_bow.nnz)
# Out:
# Shape of Sparse Matrix:  (16320, 38204)
# Amount of Non-Zero occurences:  1032069

# %%
#transform text to TFIDF format

from sklearn.feature_extraction.text import TfidfTransformer

tfidf_transformer = TfidfTransformer().fit(narrative_bow)

tfidf0 = tfidf_transformer.transform(bow0)

narrative_tfidf = tfidf_transformer.transform(narrative_bow)
print(narrative_tfidf.shape)
# Out:
# (16320, 38204)

# %%
#nbm = MultinomialNB().fit(narrative_tfidf, df_narative['Consumer disputed?'])
#print('predicted:', nbm.predict(tfidf0)[0])
#print('expected:',df_narative['Consumer disputed?'].head(1))

# %%
#print('predicted:', nbm.predict(tfidf0)[0])
#print('expected:',df_narative['Consumer disputed?'].head(1))

# %%
#random under sampling data and train-test split
from sklearn.model_selection import train_test_split

rus = RandomUnderSampler(random_state=41)
X, y = rus.fit_sample(narrative_tfidf, df_narative['Consumer disputed?'])

msg_train, msg_test, label_train, label_test = train_test_split(X, y , test_size=0.2)

#print(len(msg_train), len(msg_test), len(msg_train) + len(msg_test))

# %%
from sklearn.pipeline import Pipeline

pipeline = Pipeline([
    ('classifier', MultinomialNB()),  # train on TF-IDF vectors w/ Naive Bayes classifier
])

# %%
pipeline.fit(msg_train,label_train)
# Out:
# Pipeline(memory=None,
#      steps=[('classifier', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))])

# %%
predictions = pipeline.predict(msg_test)

# %%
scores_rf_test = cross_val_score(pipeline, X_rus_test, y_rus_test, cv=5)
print('Cross Validation Accuracy Scores - Test Set: {:.5f}(+/- {:.2f})'.format(scores_rf_test.mean(), 
                                                                                 scores_rf_test.std()*2))

from sklearn.metrics import classification_report
print('Confusion matrix on the data:')
print(confusion_matrix(label_test, predictions))
print('Classification on the data:')
print (classification_report(label_test, predictions))
# Out:
# Cross Validation Accuracy Scores - Test Set: 0.56742(+/- 0.02)
# Confusion matrix on the data:
# [[380 327]
#  [298 428]]
# Classification on the data:
#              precision    recall  f1-score   support
#
#          No       0.56      0.54      0.55       707
#         Yes       0.57      0.59      0.58       726
#
# avg / total       0.56      0.56      0.56      1433
